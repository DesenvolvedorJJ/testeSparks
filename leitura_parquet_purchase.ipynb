# %% [markdown]
# # Leitura de Múltiplos Parquets com PySpark
#
# Notebook para ler todos os arquivos Parquet de uma pasta, detectar se contêm dados JSON e expandir automaticamente.

# %% [markdown]
# ## 1. Configurar SparkSession
#
# Importar PySpark e criar uma SparkSession.

# %%
from pyspark.sql import SparkSession

# Criar SparkSession
spark = SparkSession.builder \
    .appName("Leitura Parquet") \
    .master("local[*]") \
    .getOrCreate()

print(f"Spark version: {spark.version}")
spark
# Out:
# Spark version: 3.4.0
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://pc01:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Leitura Parquet</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## 2. Resumo dos Arquivos
#
# Tabela resumo mostrando quais arquivos têm JSON e quantos registros.

# %%
import glob
import os

# Pasta com os arquivos Parquet
pasta_parquet = "quickbooks_data/daily_incremental/purchase"

# Listar todos os arquivos .parquet
arquivos = glob.glob(os.path.join(pasta_parquet, "*.parquet"))
print(f"Arquivos encontrados: {len(arquivos)}\n")

# Dicionário para guardar os DataFrames
dataframes = {}

for arquivo in arquivos:
    nome = os.path.basename(arquivo)
    print(f"--- {nome} ---")
    df = spark.read.parquet(arquivo)
    registros = df.count()
    print(f"  Registros: {registros}")
    print(f"  Colunas: {df.columns}")

    # Detectar se alguma coluna contém JSON (string que começa com '{' ou '[')
    tem_json = False
    colunas_json = []
    for c in df.columns:
        # Verificar tipo string
        tipo = dict(df.dtypes).get(c)
        if tipo == "string" and registros > 0:
            amostra = df.select(c).filter(f"`{c}` IS NOT NULL").first()
            if amostra:
                valor = amostra[0]
                if isinstance(valor, str) and len(valor) > 0 and valor.strip()[0] in ('{', '['):
                    tem_json = True
                    colunas_json.append(c)

    if tem_json:
        print(f"  ✅ Contém JSON nas colunas: {colunas_json}")
    else:
        print(f"  ❌ Não contém dados JSON")

    dataframes[nome] = {"df": df, "tem_json": tem_json, "colunas_json": colunas_json}
    print()
# Out:
# Arquivos encontrados: 3
#
# --- placeholder_purchase_20260324.parquet ---
#   Registros: 1
#   Colunas: ['raw_value']
#   ✅ Contém JSON nas colunas: ['raw_value']
#
# --- Purchase_20260207170548.parquet ---
#   Registros: 2
#   Colunas: ['raw_value']
#   ❌ Não contém dados JSON
#
# --- Purchase_20260325043100.parquet ---
#   Registros: 10
#   Colunas: ['raw_value']
#   ✅ Contém JSON nas colunas: ['raw_value']

# %% [markdown]
# import pandas as pd
#
# resumo = []
# for nome, info in dataframes.items():
#     resumo.append({
#         "Arquivo": nome,
#         "Registros": info["df"].count(),
#         "Colunas": len(info["df"].columns),
#         "Tem JSON": "Sim" if info["tem_json"] else "Não",
#         "Colunas JSON": ", ".join(info["colunas_json"]) if info["colunas_json"] else "-"
#     })
#
# df_resumo = pd.DataFrame(resumo)
# df_resumo

# %% [markdown]
# ## 3. Verificar se as Colunas JSON são Iguais
#
# Comparar os schemas JSON de todos os arquivos que contêm JSON para verificar compatibilidade.

# %%
from pyspark.sql.functions import from_json, schema_of_json, col

# Coletar schemas JSON de cada arquivo
schemas_json = {}
for nome, info in dataframes.items():
    if not info["tem_json"]:
        continue
    df = info["df"]
    for col_json in info["colunas_json"]:
        amostra = df.select(col_json).filter(f"`{col_json}` IS NOT NULL").first()[0]
        json_schema = schema_of_json(amostra)
        # Parsear para obter o StructType real
        df_temp = df.withColumn("parsed", from_json(col(col_json), json_schema)).select("parsed.*")
        schemas_json[nome] = {
            "colunas": sorted(df_temp.columns),
            "schema": df_temp.schema,
            "dtypes": sorted(df_temp.dtypes, key=lambda x: x[0])
        }

# Comparar todos os schemas entre si
arquivos_com_json = list(schemas_json.keys())
print(f"Arquivos com JSON: {len(arquivos_com_json)}\n")

if len(arquivos_com_json) < 2:
    print("⚠️ Apenas 1 arquivo com JSON encontrado, nada para comparar.")
else:
    referencia = arquivos_com_json[0]
    colunas_ref = set(schemas_json[referencia]["colunas"])
    todos_iguais = True

    for arquivo in arquivos_com_json[1:]:
        colunas_atual = set(schemas_json[arquivo]["colunas"])

        print(f"Comparando: {referencia} vs {arquivo}")

        # Colunas iguais?
        if colunas_ref == colunas_atual:
            print(f"  ✅ Mesmas colunas ({len(colunas_ref)} colunas)")
        else:
            todos_iguais = False
            apenas_ref = colunas_ref - colunas_atual
            apenas_atual = colunas_atual - colunas_ref
            em_comum = colunas_ref & colunas_atual
            print(f"  ❌ Colunas diferentes!")
            print(f"     Em comum: {len(em_comum)} → {sorted(em_comum)}")
            if apenas_ref:
                print(f"     Só em {referencia}: {sorted(apenas_ref)}")
            if apenas_atual:
                print(f"     Só em {arquivo}: {sorted(apenas_atual)}")

        # Tipos iguais?
        dtypes_ref = schemas_json[referencia]["dtypes"]
        dtypes_atual = schemas_json[arquivo]["dtypes"]
        if dtypes_ref == dtypes_atual:
            print(f"  ✅ Tipos de dados idênticos")
        else:
            todos_iguais = False
            print(f"  ❌ Tipos de dados diferem:")
            for (col_r, tipo_r), (col_a, tipo_a) in zip(dtypes_ref, dtypes_atual):
                if col_r == col_a and tipo_r != tipo_a:
                    print(f"     Coluna '{col_r}': {tipo_r} → {tipo_a}")
        print()

    if todos_iguais:
        print("✅ RESULTADO: Todos os arquivos JSON têm exatamente as mesmas colunas e tipos!")
    else:
        print("❌ RESULTADO: Existem diferenças entre os schemas JSON dos arquivos.")
# Out:
# Arquivos com JSON: 2
#
# Comparando: placeholder_purchase_20260324.parquet vs Purchase_20260325043100.parquet
#   ✅ Mesmas colunas (18 colunas)
#   ✅ Tipos de dados idênticos
#
# ✅ RESULTADO: Todos os arquivos JSON têm exatamente as mesmas colunas e tipos!

# %%
from pyspark.sql.functions import from_json, schema_of_json, col, explode_outer
from pyspark.sql.types import StructType, StringType, ArrayType

def flatten_df(df, sep="_"):
    """Achata recursivamente colunas StructType em colunas simples."""
    colunas_complexas = True
    while colunas_complexas:
        colunas_complexas = False
        novas_colunas = []
        for field in df.schema.fields:
            if isinstance(field.dataType, StructType):
                colunas_complexas = True
                for sub in field.dataType.fields:
                    novo_nome = f"{field.name}{sep}{sub.name}"
                    novas_colunas.append(df[field.name][sub.name].alias(novo_nome))
            else:
                novas_colunas.append(df[field.name])
        df = df.select(novas_colunas)
    return df

def parse_nested_json(df, sep="_", max_depth=3):
    """Detecta e parseia colunas string que contêm JSON, depois achata. Expande listas de objetos JSON."""
    for _ in range(max_depth):
        str_cols = [f.name for f in df.schema.fields if isinstance(f.dataType, StringType)]
        if not str_cols:
            break

        amostra = df.select(*[df[c] for c in str_cols]).filter(
            df[str_cols[0]].isNotNull()
        ).first()
        if not amostra:
            break

        cols_json = []
        for i, c in enumerate(str_cols):
            val = amostra[i]
            if val and isinstance(val, str) and val.strip() and val.strip()[0] in ('{', '['):
                cols_json.append((c, val))

        if not cols_json:
            break

        for c, val in cols_json:
            schema = schema_of_json(val)
            # Se for array de objetos JSON, explode para linhas
            if isinstance(schema, ArrayType):
                df = df.withColumn(c, from_json(df[c], schema))
                df = df.withColumn(c, explode_outer(col(c)))
            else:
                df = df.withColumn(c, from_json(df[c], schema))

        df = flatten_df(df, sep)
    return df

# Para cada arquivo com JSON, parsear, expandir sub-JSONs e achatar
for nome, info in dataframes.items():
    if not info["tem_json"]:
        print(f"--- {nome}: Sem JSON, mostrando dados diretos ---")
        info["df"].show(5, truncate=False)
        print()
        continue

    df = info["df"]
    for col_json in info["colunas_json"]:
        print(f"--- {nome} | Coluna: {col_json} ---")
        amostra = df.select(col_json).filter(df[col_json].isNotNull()).first()[0]
        json_schema = schema_of_json(amostra)

        # Se for array de objetos JSON, explode para linhas
        if isinstance(json_schema, ArrayType):
            df_parsed = df.withColumn("parsed", from_json(df[col_json], json_schema)) \
                          .withColumn("parsed", explode_outer(col("parsed")))
            df_parsed = df_parsed.select("parsed.*")
        else:
            df_parsed = df.withColumn("parsed", from_json(df[col_json], json_schema)) \
                          .select("parsed.*")

        colunas_antes = set(df_parsed.columns)

        # Parsear sub-JSONs e achatar tudo (agora recursivo para listas também)
        df_flat = parse_nested_json(df_parsed)

        colunas_expandidas = [c for c in df_flat.columns if c not in colunas_antes]
        if colunas_expandidas:
            print(f"Colunas JSON aninhadas expandidas: {colunas_expandidas}")

        print(f"Total de colunas: {len(df_flat.columns)}")
        df_flat.printSchema()
        df_flat.show(5, truncate=False)

        info["df_parsed"] = df_flat
    print()
# Out:
# --- placeholder_purchase_20260324.parquet | Coluna: raw_value ---
# Total de colunas: 18
# root
#  |-- AccountRef: string (nullable = true)
#  |-- Credit: string (nullable = true)
#  |-- CurrencyRef: string (nullable = true)
#  |-- DepartmentRef: string (nullable = true)
#  |-- DocNumber: string (nullable = true)
#  |-- EntityRef: string (nullable = true)
#  |-- ExchangeRate: string (nullable = true)
#  |-- Id: string (nullable = true)
#  |-- Line: string (nullable = true)
#  |-- MetaData: string (nullable = true)
#  |-- PaymentType: string (nullable = true)
#  |-- PrivateNote: string (nullable = true)
#  |-- SyncToken: string (nullable = true)
#  |-- TotalAmt: string (nullable = true)
#  |-- TxnDate: string (nullable = true)
#  |-- TxnTaxDetail: string (nullable = true)
#  |-- domain: string (nullable = true)
#  |-- sparse: string (nullable = true)
#
# +----------+------+-----------+-------------+---------+---------+------------+----------------------+----+--------+-----------+--------------------+---------+--------+----------+------------+------+------+
# |AccountRef|Credit|CurrencyRef|DepartmentRef|DocNumber|EntityRef|ExchangeRate|Id                    |Line|MetaData|PaymentType|PrivateNote         |SyncToken|TotalAmt|TxnDate   |TxnTaxDetail|domain|sparse|
# +----------+------+-----------+-------------+---------+---------+------------+----------------------+----+--------+-----------+--------------------+---------+--------+----------+------------+------+------+
# |null      |false |null       |null         |PH-PUR-1 |null     |1           |placeholder-purchase-1|null|null    |Cash       |Placeholder purchase|1        |0       |2026-02-07|null        |QBO   |false |
# +----------+------+-----------+-------------+---------+---------+------------+----------------------+----+--------+-----------+--------------------+---------+--------+----------+------------+------+------+
#
#
# --- Purchase_20260207170548.parquet: Sem JSON, mostrando dados diretos ---
# +-------------+
# |raw_value    |
# +-------------+
# |QueryResponse|
# |time         |
# +-------------+
#
#
# --- Purchase_20260325043100.parquet | Coluna: raw_value ---
# Colunas JSON aninhadas expandidas: ['AccountRef_name', 'AccountRef_value', 'CurrencyRef_name', 'CurrencyRef_value', 'DepartmentRef_name', 'DepartmentRef_value', 'EntityRef_name', 'EntityRef_type', 'EntityRef_value', 'MetaData_CreateTime', 'MetaData_LastUpdatedTime', 'MetaData_source', 'TxnTaxDetail_TotalTax']
# Total de colunas: 25
# root
#  |-- AccountRef_name: string (nullable = true)
#  |-- AccountRef_value: string (nullable = true)
#  |-- Credit: string (nullable = true)
#  |-- CurrencyRef_name: string (nullable = true)
#  |-- CurrencyRef_value: string (nullable = true)
#  |-- DepartmentRef_name: string (nullable = true)
#  |-- DepartmentRef_value: string (nullable = true)
#  |-- DocNumber: string (nullable = true)
#  |-- EntityRef_name: string (nullable = true)
#  |-- EntityRef_type: string (nullable = true)
#  |-- EntityRef_value: string (nullable = true)
#  |-- ExchangeRate: string (nullable = true)
#  |-- Id: string (nullable = true)
#  |-- Line: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- Amount: string (nullable = true)
#  |    |    |-- Description: string (nullable = true)
#  |    |    |-- DetailType: string (nullable = true)
#  |-- MetaData_CreateTime: string (nullable = true)
#  |-- MetaData_LastUpdatedTime: string (nullable = true)
#  |-- MetaData_source: string (nullable = true)
#  |-- PaymentType: string (nullable = true)
#  |-- PrivateNote: string (nullable = true)
#  |-- SyncToken: string (nullable = true)
#  |-- TotalAmt: string (nullable = true)
#  |-- TxnDate: string (nullable = true)
#  |-- TxnTaxDetail_TotalTax: string (nullable = true)
#  |-- domain: string (nullable = true)
#  |-- sparse: string (nullable = true)
#
# +---------------+----------------+------+--------------------+-----------------+------------------+-------------------+---------+-----------------+--------------+---------------+------------+------------+----------------------------------------------------------+--------------------+------------------------+---------------+-----------+---------------+---------+--------+----------+---------------------+------+------+
# |AccountRef_name|AccountRef_value|Credit|CurrencyRef_name    |CurrencyRef_value|DepartmentRef_name|DepartmentRef_value|DocNumber|EntityRef_name   |EntityRef_type|EntityRef_value|ExchangeRate|Id          |Line                                                      |MetaData_CreateTime |MetaData_LastUpdatedTime|MetaData_source|PaymentType|PrivateNote    |SyncToken|TotalAmt|TxnDate   |TxnTaxDetail_TotalTax|domain|sparse|
# +---------------+----------------+------+--------------------+-----------------+------------------+-------------------+---------+-----------------+--------------+---------------+------------+------------+----------------------------------------------------------+--------------------+------------------------+---------------+-----------+---------------+---------+--------+----------+---------------------+------+------+
# |Office Expense |acct-002        |false |United States Dollar|USD              |Clinical          |dep-2              |PUR-9001 |Clinical Vendor 1|Vendor        |vend-001       |1           |purchase-001|[{118.40, Purchase line 1, AccountBasedExpenseLineDetail}]|2026-02-02T09:00:00Z|2026-03-02T09:30:00Z    |purchase       |Check      |Purchase note 1|801      |118.40  |2026-03-01|5.92                 |QBO   |false |
# |Office Expense |acct-002        |false |United States Dollar|USD              |Admin             |dep-3              |PUR-9002 |Clinical Vendor 2|Vendor        |vend-002       |1           |purchase-002|[{146.80, Purchase line 2, AccountBasedExpenseLineDetail}]|2026-02-03T09:00:00Z|2026-03-03T10:30:00Z    |purchase       |CreditCard |Purchase note 2|802      |146.80  |2026-03-02|7.34                 |QBO   |false |
# |Office Expense |acct-002        |false |United States Dollar|USD              |Front Office      |dep-1              |PUR-9003 |Clinical Vendor 3|Vendor        |vend-003       |1           |purchase-003|[{175.20, Purchase line 3, AccountBasedExpenseLineDetail}]|2026-02-04T09:00:00Z|2026-03-04T11:30:00Z    |purchase       |Cash       |Purchase note 3|803      |175.20  |2026-03-03|8.76                 |QBO   |false |
# |Office Expense |acct-002        |false |United States Dollar|USD              |Clinical          |dep-2              |PUR-9004 |Clinical Vendor 4|Vendor        |vend-004       |1           |purchase-004|[{203.60, Purchase line 4, AccountBasedExpenseLineDetail}]|2026-02-05T09:00:00Z|2026-03-05T12:30:00Z    |purchase       |Check      |Purchase note 4|804      |203.60  |2026-03-04|10.18                |QBO   |false |
# |Office Expense |acct-002        |false |United States Dollar|USD              |Admin             |dep-3              |PUR-9005 |Clinical Vendor 5|Vendor        |vend-005       |1           |purchase-005|[{232.00, Purchase line 5, AccountBasedExpenseLineDetail}]|2026-02-06T09:00:00Z|2026-03-06T13:30:00Z    |purchase       |CreditCard |Purchase note 5|805      |232.00  |2026-03-05|11.60                |QBO   |false |
# +---------------+----------------+------+--------------------+-----------------+------------------+-------------------+---------+-----------------+--------------+---------------+------------+------------+----------------------------------------------------------+--------------------+------------------------+---------------+-----------+---------------+---------+--------+----------+---------------------+------+------+
# only showing top 5 rows

# %%
from IPython.display import display
from functools import reduce
from pyspark.sql.functions import col, count, when
from pyspark.sql.types import StringType, ArrayType

# Juntar todos os DataFrames parseados em um só, tratando diferenças de schema e tipos

dfs_parsed = [info["df_parsed"] for info in dataframes.values() if "df_parsed" in info]

def explode_and_flatten_line(df):
    # Se existir coluna 'Line' e for array, explode e flatten
    if 'Line' in df.columns:
        tipo = dict(df.dtypes).get('Line')
        if tipo == 'array<string>' or tipo == 'array<struct<' or isinstance(df.schema['Line'].dataType, ArrayType):
            from pyspark.sql.functions import explode_outer, from_json, schema_of_json
            # Detectar schema do primeiro valor não nulo
            amostra = df.select('Line').filter(col('Line').isNotNull()).first()
            if amostra and amostra[0] is not None and len(amostra[0]) > 0:
                # Se for array de string JSON, parsear cada elemento
                if isinstance(amostra[0][0], str):
                    schema = schema_of_json(amostra[0][0])
                    df = df.withColumn('Line', explode_outer(col('Line')))
                    df = df.withColumn('Line', from_json(col('Line'), schema))
                else:
                    df = df.withColumn('Line', explode_outer(col('Line')))
                # Flatten Line
                line_cols = [f"Line_{c.name}" for c in df.schema['Line'].dataType.fields] if hasattr(df.schema['Line'].dataType, 'fields') else []
                if line_cols:
                    df = df.select('*', *[col('Line')[c].alias(f'Line_{c}') for c in df.schema['Line'].dataType.fieldNames()])
                    df = df.drop('Line')
    return df

if dfs_parsed:
    dfs_flat = [explode_and_flatten_line(df) for df in dfs_parsed]
    # Não converter para string, unir por nome de coluna
    df_merged = reduce(lambda a, b: a.unionByName(b, allowMissingColumns=True), dfs_flat)

    # Identificar e remover colunas que são totalmente nulas
    total = df_merged.count()
    nulls_por_coluna = df_merged.select(
        [count(when(col(c).isNull(), c)).alias(c) for c in df_merged.columns]
    ).first()

    colunas_nulas = [c for c in df_merged.columns if nulls_por_coluna[c] == total]
    if colunas_nulas:
        print(f"Colunas totalmente nulas removidas: {colunas_nulas}")
        df_merged = df_merged.drop(*colunas_nulas)

    print(f"Total de linhas: {total} | Total de colunas: {len(df_merged.columns)}")
    df_merged.show(10, truncate=False)
else:
    print("Nenhum DataFrame parseado encontrado.")
# Out:
# Colunas totalmente nulas removidas: ['AccountRef', 'CurrencyRef', 'DepartmentRef', 'EntityRef', 'Line', 'MetaData', 'TxnTaxDetail']
# Total de linhas: 11 | Total de colunas: 27
# +------+---------+------------+----------------------+-----------+--------------------+---------+--------+----------+------+------+---------------+----------------+--------------------+-----------------+------------------+-------------------+-----------------+--------------+---------------+--------------------+------------------------+---------------+---------------------+-----------+----------------+-----------------------------+
# |Credit|DocNumber|ExchangeRate|Id                    |PaymentType|PrivateNote         |SyncToken|TotalAmt|TxnDate   |domain|sparse|AccountRef_name|AccountRef_value|CurrencyRef_name    |CurrencyRef_value|DepartmentRef_name|DepartmentRef_value|EntityRef_name   |EntityRef_type|EntityRef_value|MetaData_CreateTime |MetaData_LastUpdatedTime|MetaData_source|TxnTaxDetail_TotalTax|Line_Amount|Line_Description|Line_DetailType              |
# +------+---------+------------+----------------------+-----------+--------------------+---------+--------+----------+------+------+---------------+----------------+--------------------+-----------------+------------------+-------------------+-----------------+--------------+---------------+--------------------+------------------------+---------------+---------------------+-----------+----------------+-----------------------------+
# |false |PH-PUR-1 |1           |placeholder-purchase-1|Cash       |Placeholder purchase|1        |0       |2026-02-07|QBO   |false |null           |null            |null                |null             |null              |null               |null             |null          |null           |null                |null                    |null           |null                 |null       |null            |null                         |
# |false |PUR-9001 |1           |purchase-001          |Check      |Purchase note 1     |801      |118.40  |2026-03-01|QBO   |false |Office Expense |acct-002        |United States Dollar|USD              |Clinical          |dep-2              |Clinical Vendor 1|Vendor        |vend-001       |2026-02-02T09:00:00Z|2026-03-02T09:30:00Z    |purchase       |5.92                 |118.40     |Purchase line 1 |AccountBasedExpenseLineDetail|
# |false |PUR-9002 |1           |purchase-002          |CreditCard |Purchase note 2     |802      |146.80  |2026-03-02|QBO   |false |Office Expense |acct-002        |United States Dollar|USD              |Admin             |dep-3              |Clinical Vendor 2|Vendor        |vend-002       |2026-02-03T09:00:00Z|2026-03-03T10:30:00Z    |purchase       |7.34                 |146.80     |Purchase line 2 |AccountBasedExpenseLineDetail|
# |false |PUR-9003 |1           |purchase-003          |Cash       |Purchase note 3     |803      |175.20  |2026-03-03|QBO   |false |Office Expense |acct-002        |United States Dollar|USD              |Front Office      |dep-1              |Clinical Vendor 3|Vendor        |vend-003       |2026-02-04T09:00:00Z|2026-03-04T11:30:00Z    |purchase       |8.76                 |175.20     |Purchase line 3 |AccountBasedExpenseLineDetail|
# |false |PUR-9004 |1           |purchase-004          |Check      |Purchase note 4     |804      |203.60  |2026-03-04|QBO   |false |Office Expense |acct-002        |United States Dollar|USD              |Clinical          |dep-2              |Clinical Vendor 4|Vendor        |vend-004       |2026-02-05T09:00:00Z|2026-03-05T12:30:00Z    |purchase       |10.18                |203.60     |Purchase line 4 |AccountBasedExpenseLineDetail|
# |false |PUR-9005 |1           |purchase-005          |CreditCard |Purchase note 5     |805      |232.00  |2026-03-05|QBO   |false |Office Expense |acct-002        |United States Dollar|USD              |Admin             |dep-3              |Clinical Vendor 5|Vendor        |vend-005       |2026-02-06T09:00:00Z|2026-03-06T13:30:00Z    |purchase       |11.60                |232.00     |Purchase line 5 |AccountBasedExpenseLineDetail|
# |false |PUR-9006 |1           |purchase-006          |Cash       |Purchase note 6     |806      |260.40  |2026-03-06|QBO   |false |Office Expense |acct-002        |United States Dollar|USD              |Front Office      |dep-1              |Clinical Vendor 6|Vendor        |vend-006       |2026-02-07T09:00:00Z|2026-03-07T14:30:00Z    |purchase       |13.02                |260.40     |Purchase line 6 |AccountBasedExpenseLineDetail|
# |false |PUR-9007 |1           |purchase-007          |Check      |Purchase note 7     |807      |288.80  |2026-03-07|QBO   |false |Office Expense |acct-002        |United States Dollar|USD              |Clinical          |dep-2              |Clinical Vendor 7|Vendor        |vend-007       |2026-02-08T09:00:00Z|2026-03-08T15:30:00Z    |purchase       |14.44                |288.80     |Purchase line 7 |AccountBasedExpenseLineDetail|
# |false |PUR-9008 |1           |purchase-008          |CreditCard |Purchase note 8     |808      |317.20  |2026-03-08|QBO   |false |Office Expense |acct-002        |United States Dollar|USD              |Admin             |dep-3              |Clinical Vendor 8|Vendor        |vend-008       |2026-02-09T09:00:00Z|2026-03-09T16:30:00Z    |purchase       |15.86                |317.20     |Purchase line 8 |AccountBasedExpenseLineDetail|
# |false |PUR-9009 |1           |purchase-009          |Cash       |Purchase note 9     |809      |345.60  |2026-03-09|QBO   |false |Office Expense |acct-002        |United States Dollar|USD              |Front Office      |dep-1              |Clinical Vendor 9|Vendor        |vend-009       |2026-02-10T09:00:00Z|2026-03-10T17:30:00Z    |purchase       |17.28                |345.60     |Purchase line 9 |AccountBasedExpenseLineDetail|
# +------+---------+------------+----------------------+-----------+--------------------+---------+--------+----------+------+------+---------------+----------------+--------------------+-----------------+------------------+-------------------+-----------------+--------------+---------------+--------------------+------------------------+---------------+---------------------+-----------+----------------+-----------------------------+
# only showing top 10 rows

# %%
# Encerrar SparkSession
spark.stop()
print("SparkSession encerrada.")
# Out:
# SparkSession encerrada.
