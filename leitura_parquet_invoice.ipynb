# %% [markdown]
# # Leitura de Múltiplos Parquets com PySpark
#
# Notebook para ler todos os arquivos Parquet de uma pasta, detectar se contêm dados JSON e expandir automaticamente.

# %% [markdown]
# ## 1. Configurar SparkSession
#
# Importar PySpark e criar uma SparkSession.

# %%
from pyspark.sql import SparkSession

# Criar SparkSession
spark = SparkSession.builder \
    .appName("Leitura Parquet") \
    .master("local[*]") \
    .getOrCreate()

print(f"Spark version: {spark.version}")
spark
# Out:
# Spark version: 3.4.0
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://pc01:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Leitura Parquet</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## 2. Resumo dos Arquivos
#
# Tabela resumo mostrando quais arquivos têm JSON e quantos registros.

# %%
import glob
import os

# Pasta com os arquivos Parquet
pasta_parquet = "quickbooks_data/daily_incremental/invoice"

# Listar todos os arquivos .parquet
arquivos = glob.glob(os.path.join(pasta_parquet, "*.parquet"))
print(f"Arquivos encontrados: {len(arquivos)}\n")

# Dicionário para guardar os DataFrames
dataframes = {}

for arquivo in arquivos:
    nome = os.path.basename(arquivo)
    print(f"--- {nome} ---")
    df = spark.read.parquet(arquivo)
    registros = df.count()
    print(f"  Registros: {registros}")
    print(f"  Colunas: {df.columns}")

    # Detectar se alguma coluna contém JSON (string que começa com '{' ou '[')
    tem_json = False
    colunas_json = []
    for c in df.columns:
        # Verificar tipo string
        tipo = dict(df.dtypes).get(c)
        if tipo == "string" and registros > 0:
            amostra = df.select(c).filter(f"`{c}` IS NOT NULL").first()
            if amostra:
                valor = amostra[0]
                if isinstance(valor, str) and len(valor) > 0 and valor.strip()[0] in ('{', '['):
                    tem_json = True
                    colunas_json.append(c)

    if tem_json:
        print(f"  ✅ Contém JSON nas colunas: {colunas_json}")
    else:
        print(f"  ❌ Não contém dados JSON")

    dataframes[nome] = {"df": df, "tem_json": tem_json, "colunas_json": colunas_json}
    print()
# Out:
# Arquivos encontrados: 3
#
# --- Invoice_20260207170547.parquet ---
#   Registros: 2
#   Colunas: ['raw_value']
#   ❌ Não contém dados JSON
#
# --- Invoice_20260325043100.parquet ---
#   Registros: 10
#   Colunas: ['raw_value']
#   ✅ Contém JSON nas colunas: ['raw_value']
#
# --- placeholder_invoice_20260324.parquet ---
#   Registros: 1
#   Colunas: ['raw_value']
#   ✅ Contém JSON nas colunas: ['raw_value']

# %% [markdown]
# import pandas as pd
#
# resumo = []
# for nome, info in dataframes.items():
#     resumo.append({
#         "Arquivo": nome,
#         "Registros": info["df"].count(),
#         "Colunas": len(info["df"].columns),
#         "Tem JSON": "Sim" if info["tem_json"] else "Não",
#         "Colunas JSON": ", ".join(info["colunas_json"]) if info["colunas_json"] else "-"
#     })
#
# df_resumo = pd.DataFrame(resumo)
# df_resumo

# %% [markdown]
# ## 3. Verificar se as Colunas JSON são Iguais
#
# Comparar os schemas JSON de todos os arquivos que contêm JSON para verificar compatibilidade.

# %%
from pyspark.sql.functions import from_json, schema_of_json, col

# Coletar schemas JSON de cada arquivo
schemas_json = {}
for nome, info in dataframes.items():
    if not info["tem_json"]:
        continue
    df = info["df"]
    for col_json in info["colunas_json"]:
        amostra = df.select(col_json).filter(f"`{col_json}` IS NOT NULL").first()[0]
        json_schema = schema_of_json(amostra)
        # Parsear para obter o StructType real
        df_temp = df.withColumn("parsed", from_json(col(col_json), json_schema)).select("parsed.*")
        schemas_json[nome] = {
            "colunas": sorted(df_temp.columns),
            "schema": df_temp.schema,
            "dtypes": sorted(df_temp.dtypes, key=lambda x: x[0])
        }

# Comparar todos os schemas entre si
arquivos_com_json = list(schemas_json.keys())
print(f"Arquivos com JSON: {len(arquivos_com_json)}\n")

if len(arquivos_com_json) < 2:
    print("⚠️ Apenas 1 arquivo com JSON encontrado, nada para comparar.")
else:
    referencia = arquivos_com_json[0]
    colunas_ref = set(schemas_json[referencia]["colunas"])
    todos_iguais = True

    for arquivo in arquivos_com_json[1:]:
        colunas_atual = set(schemas_json[arquivo]["colunas"])

        print(f"Comparando: {referencia} vs {arquivo}")

        # Colunas iguais?
        if colunas_ref == colunas_atual:
            print(f"  ✅ Mesmas colunas ({len(colunas_ref)} colunas)")
        else:
            todos_iguais = False
            apenas_ref = colunas_ref - colunas_atual
            apenas_atual = colunas_atual - colunas_ref
            em_comum = colunas_ref & colunas_atual
            print(f"  ❌ Colunas diferentes!")
            print(f"     Em comum: {len(em_comum)} → {sorted(em_comum)}")
            if apenas_ref:
                print(f"     Só em {referencia}: {sorted(apenas_ref)}")
            if apenas_atual:
                print(f"     Só em {arquivo}: {sorted(apenas_atual)}")

        # Tipos iguais?
        dtypes_ref = schemas_json[referencia]["dtypes"]
        dtypes_atual = schemas_json[arquivo]["dtypes"]
        if dtypes_ref == dtypes_atual:
            print(f"  ✅ Tipos de dados idênticos")
        else:
            todos_iguais = False
            print(f"  ❌ Tipos de dados diferem:")
            for (col_r, tipo_r), (col_a, tipo_a) in zip(dtypes_ref, dtypes_atual):
                if col_r == col_a and tipo_r != tipo_a:
                    print(f"     Coluna '{col_r}': {tipo_r} → {tipo_a}")
        print()

    if todos_iguais:
        print("✅ RESULTADO: Todos os arquivos JSON têm exatamente as mesmas colunas e tipos!")
    else:
        print("❌ RESULTADO: Existem diferenças entre os schemas JSON dos arquivos.")
# Out:
# Arquivos com JSON: 2
#
# Comparando: Invoice_20260325043100.parquet vs placeholder_invoice_20260324.parquet
#   ✅ Mesmas colunas (27 colunas)
#   ✅ Tipos de dados idênticos
#
# ✅ RESULTADO: Todos os arquivos JSON têm exatamente as mesmas colunas e tipos!

# %%
from pyspark.sql.functions import from_json, schema_of_json, col
from pyspark.sql.types import StructType, StringType

def flatten_df(df, sep="_"):
    """Achata recursivamente colunas StructType em colunas simples."""
    colunas_complexas = True
    while colunas_complexas:
        colunas_complexas = False
        novas_colunas = []
        for field in df.schema.fields:
            if isinstance(field.dataType, StructType):
                colunas_complexas = True
                for sub in field.dataType.fields:
                    novo_nome = f"{field.name}{sep}{sub.name}"
                    novas_colunas.append(df[field.name][sub.name].alias(novo_nome))
            else:
                novas_colunas.append(df[field.name])
        df = df.select(novas_colunas)
    return df

def parse_nested_json(df, sep="_", max_depth=3):
    """Detecta e parseia colunas string que contêm JSON, depois achata."""
    for _ in range(max_depth):
        str_cols = [f.name for f in df.schema.fields if isinstance(f.dataType, StringType)]
        if not str_cols:
            break

        amostra = df.select(*[df[c] for c in str_cols]).filter(
            df[str_cols[0]].isNotNull()
        ).first()
        if not amostra:
            break

        cols_json = []
        for i, c in enumerate(str_cols):
            val = amostra[i]
            if val and isinstance(val, str) and val.strip() and val.strip()[0] in ('{', '['):
                cols_json.append((c, val))

        if not cols_json:
            break

        for c, val in cols_json:
            schema = schema_of_json(val)
            df = df.withColumn(c, from_json(df[c], schema))

        df = flatten_df(df, sep)
    return df

# Para cada arquivo com JSON, parsear, expandir sub-JSONs e achatar
for nome, info in dataframes.items():
    if not info["tem_json"]:
        print(f"--- {nome}: Sem JSON, mostrando dados diretos ---")
        info["df"].show(5, truncate=False)
        print()
        continue

    df = info["df"]
    for col_json in info["colunas_json"]:
        print(f"--- {nome} | Coluna: {col_json} ---")
        amostra = df.select(col_json).filter(df[col_json].isNotNull()).first()[0]
        json_schema = schema_of_json(amostra)

        df_parsed = df.withColumn("parsed", from_json(df[col_json], json_schema)) \
                      .select("parsed.*")

        colunas_antes = set(df_parsed.columns)

        # Parsear sub-JSONs e achatar tudo
        df_flat = parse_nested_json(df_parsed)

        colunas_expandidas = [c for c in df_flat.columns if c not in colunas_antes]
        if colunas_expandidas:
            print(f"Colunas JSON aninhadas expandidas: {colunas_expandidas}")

        print(f"Total de colunas: {len(df_flat.columns)}")
        df_flat.printSchema()
        df_flat.show(5, truncate=False)

        info["df_parsed"] = df_flat
    print()
# Out:
# --- Invoice_20260207170547.parquet: Sem JSON, mostrando dados diretos ---
# +-------------+
# |raw_value    |
# +-------------+
# |QueryResponse|
# |time         |
# +-------------+
#
#
# --- Invoice_20260325043100.parquet | Coluna: raw_value ---
# Colunas JSON aninhadas expandidas: ['BillAddr_City', 'BillAddr_CountrySubDivisionCode', 'BillAddr_Line1', 'BillAddr_PostalCode', 'ClassRef_name', 'ClassRef_value', 'CurrencyRef_name', 'CurrencyRef_value', 'CustomerMemo_value', 'CustomerRef_name', 'CustomerRef_value', 'DepartmentRef_name', 'DepartmentRef_value', 'DepositToAccountRef_name', 'DepositToAccountRef_value', 'MetaData_CreateTime', 'MetaData_LastUpdatedTime', 'MetaData_source', 'SalesTermRef_name', 'SalesTermRef_value', 'ShipAddr_City', 'ShipAddr_CountrySubDivisionCode', 'ShipAddr_Line1', 'ShipAddr_PostalCode', 'TxnTaxDetail_TotalTax']
# Total de colunas: 41
# root
#  |-- Balance: string (nullable = true)
#  |-- BillAddr_City: string (nullable = true)
#  |-- BillAddr_CountrySubDivisionCode: string (nullable = true)
#  |-- BillAddr_Line1: string (nullable = true)
#  |-- BillAddr_PostalCode: string (nullable = true)
#  |-- ClassRef_name: string (nullable = true)
#  |-- ClassRef_value: string (nullable = true)
#  |-- CurrencyRef_name: string (nullable = true)
#  |-- CurrencyRef_value: string (nullable = true)
#  |-- CustomerMemo_value: string (nullable = true)
#  |-- CustomerRef_name: string (nullable = true)
#  |-- CustomerRef_value: string (nullable = true)
#  |-- DepartmentRef_name: string (nullable = true)
#  |-- DepartmentRef_value: string (nullable = true)
#  |-- DepositToAccountRef_name: string (nullable = true)
#  |-- DepositToAccountRef_value: string (nullable = true)
#  |-- DocNumber: string (nullable = true)
#  |-- DueDate: string (nullable = true)
#  |-- EmailStatus: string (nullable = true)
#  |-- ExchangeRate: string (nullable = true)
#  |-- Id: string (nullable = true)
#  |-- Line: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- Amount: string (nullable = true)
#  |    |    |-- Description: string (nullable = true)
#  |    |    |-- DetailType: string (nullable = true)
#  |-- LinkedTxn: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- TxnId: string (nullable = true)
#  |    |    |-- TxnType: string (nullable = true)
#  |-- MetaData_CreateTime: string (nullable = true)
#  |-- MetaData_LastUpdatedTime: string (nullable = true)
#  |-- MetaData_source: string (nullable = true)
#  |-- PrintStatus: string (nullable = true)
#  |-- PrivateNote: string (nullable = true)
#  |-- SalesTermRef_name: string (nullable = true)
#  |-- SalesTermRef_value: string (nullable = true)
#  |-- ShipAddr_City: string (nullable = true)
#  |-- ShipAddr_CountrySubDivisionCode: string (nullable = true)
#  |-- ShipAddr_Line1: string (nullable = true)
#  |-- ShipAddr_PostalCode: string (nullable = true)
#  |-- ShipDate: string (nullable = true)
#  |-- SyncToken: string (nullable = true)
#  |-- TotalAmt: string (nullable = true)
#  |-- TxnDate: string (nullable = true)
#  |-- TxnTaxDetail_TotalTax: string (nullable = true)
#  |-- domain: string (nullable = true)
#  |-- sparse: string (nullable = true)
#
# +-------+-------------+-------------------------------+--------------+-------------------+-------------+--------------+--------------------+-----------------+--------------------------+----------------+-----------------+------------------+-------------------+------------------------+-------------------------+---------+----------+-----------+------------+-------+----------------------------------------------------+--------------------+--------------------+------------------------+---------------+-------------+--------------+-----------------+------------------+-------------+-------------------------------+--------------+-------------------+----------+---------+--------+----------+---------------------+------+------+
# |Balance|BillAddr_City|BillAddr_CountrySubDivisionCode|BillAddr_Line1|BillAddr_PostalCode|ClassRef_name|ClassRef_value|CurrencyRef_name    |CurrencyRef_value|CustomerMemo_value        |CustomerRef_name|CustomerRef_value|DepartmentRef_name|DepartmentRef_value|DepositToAccountRef_name|DepositToAccountRef_value|DocNumber|DueDate   |EmailStatus|ExchangeRate|Id     |Line                                                |LinkedTxn           |MetaData_CreateTime |MetaData_LastUpdatedTime|MetaData_source|PrintStatus  |PrivateNote   |SalesTermRef_name|SalesTermRef_value|ShipAddr_City|ShipAddr_CountrySubDivisionCode|ShipAddr_Line1|ShipAddr_PostalCode|ShipDate  |SyncToken|TotalAmt|TxnDate   |TxnTaxDetail_TotalTax|domain|sparse|
# +-------+-------------+-------------------------------+--------------+-------------------+-------------+--------------+--------------------+-----------------+--------------------------+----------------+-----------------+------------------+-------------------+------------------------+-------------------------+---------+----------+-----------+------------+-------+----------------------------------------------------+--------------------+--------------------+------------------------+---------------+-------------+--------------+-----------------+------------------+-------------+-------------------------------+--------------+-------------------+----------+---------+--------+----------+---------------------+------+------+
# |25.25  |Sylacauga    |AL                             |101 Main St   |35151              |Specialty    |class-2       |United States Dollar|USD              |Thank you for your visit 1|Patient 1       |cust-001         |Clinical          |dep-2              |Operating Account 1     |acct-001                 |INV-5001 |2026-04-01|EmailSent  |1           |inv-001|[{222.25, Procedure package 1, SalesItemLineDetail}]|[{pay-001, Payment}]|2026-02-02T09:00:00Z|2026-03-02T09:30:00Z    |invoice        |NeedToPrint  |Invoice note 1|Net 30           |term-001          |Sylacauga    |AL                             |101 Main St   |35151              |2026-03-01|501      |222.25  |2026-03-01|13.33                |QBO   |false |
# |30.50  |Sylacauga    |AL                             |102 Main St   |35152              |General      |class-1       |United States Dollar|USD              |Thank you for your visit 2|Patient 2       |cust-002         |Admin             |dep-3              |Operating Account 1     |acct-001                 |INV-5002 |2026-04-02|EmailSent  |1           |inv-002|[{264.50, Procedure package 2, SalesItemLineDetail}]|[{pay-002, Payment}]|2026-02-03T09:00:00Z|2026-03-03T10:30:00Z    |invoice        |PrintComplete|Invoice note 2|Net 30           |term-001          |Sylacauga    |AL                             |102 Main St   |35152              |2026-03-02|502      |264.50  |2026-03-02|15.87                |QBO   |false |
# |35.75  |Sylacauga    |AL                             |103 Main St   |35153              |Specialty    |class-2       |United States Dollar|USD              |Thank you for your visit 3|Patient 3       |cust-003         |Front Office      |dep-1              |Operating Account 1     |acct-001                 |INV-5003 |2026-04-03|EmailSent  |1           |inv-003|[{306.75, Procedure package 3, SalesItemLineDetail}]|[{pay-003, Payment}]|2026-02-04T09:00:00Z|2026-03-04T11:30:00Z    |invoice        |NeedToPrint  |Invoice note 3|Net 30           |term-001          |Sylacauga    |AL                             |103 Main St   |35153              |2026-03-03|503      |306.75  |2026-03-03|18.40                |QBO   |false |
# |41.00  |Sylacauga    |AL                             |104 Main St   |35154              |General      |class-1       |United States Dollar|USD              |Thank you for your visit 4|Patient 4       |cust-004         |Clinical          |dep-2              |Operating Account 1     |acct-001                 |INV-5004 |2026-04-04|EmailSent  |1           |inv-004|[{349.00, Procedure package 4, SalesItemLineDetail}]|[{pay-004, Payment}]|2026-02-05T09:00:00Z|2026-03-05T12:30:00Z    |invoice        |PrintComplete|Invoice note 4|Net 30           |term-001          |Sylacauga    |AL                             |104 Main St   |35154              |2026-03-04|504      |349.00  |2026-03-04|20.94                |QBO   |false |
# |46.25  |Sylacauga    |AL                             |105 Main St   |35155              |Specialty    |class-2       |United States Dollar|USD              |Thank you for your visit 5|Patient 5       |cust-005         |Admin             |dep-3              |Operating Account 1     |acct-001                 |INV-5005 |2026-04-05|EmailSent  |1           |inv-005|[{391.25, Procedure package 5, SalesItemLineDetail}]|[{pay-005, Payment}]|2026-02-06T09:00:00Z|2026-03-06T13:30:00Z    |invoice        |NeedToPrint  |Invoice note 5|Net 30           |term-001          |Sylacauga    |AL                             |105 Main St   |35155              |2026-03-05|505      |391.25  |2026-03-05|23.47                |QBO   |false |
# +-------+-------------+-------------------------------+--------------+-------------------+-------------+--------------+--------------------+-----------------+--------------------------+----------------+-----------------+------------------+-------------------+------------------------+-------------------------+---------+----------+-----------+------------+-------+----------------------------------------------------+--------------------+--------------------+------------------------+---------------+-------------+--------------+-----------------+------------------+-------------+-------------------------------+--------------+-------------------+----------+---------+--------+----------+---------------------+------+------+
# only showing top 5 rows
#
#
# --- placeholder_invoice_20260324.parquet | Coluna: raw_value ---
# Total de colunas: 27
# root
#  |-- Balance: string (nullable = true)
#  |-- BillAddr: string (nullable = true)
#  |-- ClassRef: string (nullable = true)
#  |-- CurrencyRef: string (nullable = true)
#  |-- CustomerMemo: string (nullable = true)
#  |-- CustomerRef: string (nullable = true)
#  |-- DepartmentRef: string (nullable = true)
#  |-- DepositToAccountRef: string (nullable = true)
#  |-- DocNumber: string (nullable = true)
#  |-- DueDate: string (nullable = true)
#  |-- EmailStatus: string (nullable = true)
#  |-- ExchangeRate: string (nullable = true)
#  |-- Id: string (nullable = true)
#  |-- Line: string (nullable = true)
#  |-- LinkedTxn: string (nullable = true)
#  |-- MetaData: string (nullable = true)
#  |-- PrintStatus: string (nullable = true)
#  |-- PrivateNote: string (nullable = true)
#  |-- SalesTermRef: string (nullable = true)
#  |-- ShipAddr: string (nullable = true)
#  |-- ShipDate: string (nullable = true)
#  |-- SyncToken: string (nullable = true)
#  |-- TotalAmt: string (nullable = true)
#  |-- TxnDate: string (nullable = true)
#  |-- TxnTaxDetail: string (nullable = true)
#  |-- domain: string (nullable = true)
#  |-- sparse: string (nullable = true)
#
# +-------+--------+--------+-----------+------------+-----------+-------------+-------------------+---------+----------+-----------+------------+---------------------+----+---------+--------+-----------+-------------------+------------+--------+----------+---------+--------+----------+------------+------+------+
# |Balance|BillAddr|ClassRef|CurrencyRef|CustomerMemo|CustomerRef|DepartmentRef|DepositToAccountRef|DocNumber|DueDate   |EmailStatus|ExchangeRate|Id                   |Line|LinkedTxn|MetaData|PrintStatus|PrivateNote        |SalesTermRef|ShipAddr|ShipDate  |SyncToken|TotalAmt|TxnDate   |TxnTaxDetail|domain|sparse|
# +-------+--------+--------+-----------+------------+-----------+-------------+-------------------+---------+----------+-----------+------------+---------------------+----+---------+--------+-----------+-------------------+------------+--------+----------+---------+--------+----------+------------+------+------+
# |0      |null    |null    |null       |null        |null       |null         |null               |PH-INV-1 |2026-02-14|NotSet     |1           |placeholder-invoice-1|null|null     |null    |NotSet     |Placeholder invoice|null        |null    |2026-02-07|1        |0       |2026-02-07|null        |QBO   |false |
# +-------+--------+--------+-----------+------------+-----------+-------------+-------------------+---------+----------+-----------+------------+---------------------+----+---------+--------+-----------+-------------------+------------+--------+----------+---------+--------+----------+------------+------+------+

# %%
from IPython.display import display

# Mostrar as 5 primeiras linhas da tabela final de cada arquivo
for nome, info in dataframes.items():
    if "df_parsed" in info:
        print(f"\n--- {nome} (5 primeiras linhas) ---")
        display(info["df_parsed"].limit(5).toPandas())
# Out:
# --- Invoice_20260325043100.parquet (5 primeiras linhas) ---
#   Balance BillAddr_City BillAddr_CountrySubDivisionCode BillAddr_Line1  \
# 0   25.25     Sylacauga                              AL    101 Main St
# 1   30.50     Sylacauga                              AL    102 Main St
# 2   35.75     Sylacauga                              AL    103 Main St
# 3   41.00     Sylacauga                              AL    104 Main St
# 4   46.25     Sylacauga                              AL    105 Main St
#
#   BillAddr_PostalCode ClassRef_name ClassRef_value      CurrencyRef_name  \
# 0               35151     Specialty        class-2  United States Dollar
# 1               35152       General        class-1  United States Dollar
# 2               35153     Specialty        class-2  United States Dollar
# 3               35154       General        class-1  United States Dollar
# 4               35155     Specialty        class-2  United States Dollar
#
#   CurrencyRef_value          CustomerMemo_value  ...  \
# 0               USD  Thank you for your visit 1  ...
# 1               USD  Thank you for your visit 2  ...
# 2               USD  Thank you for your visit 3  ...
# 3               USD  Thank you for your visit 4  ...
# 4               USD  Thank you for your visit 5  ...
#
#   ShipAddr_CountrySubDivisionCode ShipAddr_Line1 ShipAddr_PostalCode  \
# 0                              AL    101 Main St               35151
# 1                              AL    102 Main St               35152
# 2                              AL    103 Main St               35153
# 3                              AL    104 Main St               35154
# 4                              AL    105 Main St               35155
#
#      ShipDate SyncToken TotalAmt     TxnDate TxnTaxDetail_TotalTax domain  \
# 0  2026-03-01       501   222.25  2026-03-01                 13.33    QBO
# 1  2026-03-02       502   264.50  2026-03-02                 15.87    QBO
# 2  2026-03-03       503   306.75  2026-03-03                 18.40    QBO
# 3  2026-03-04       504   349.00  2026-03-04                 20.94    QBO
# 4  2026-03-05       505   391.25  2026-03-05                 23.47    QBO
#
#   sparse
# 0  false
# 1  false
# 2  false
# 3  false
# 4  false
#
# [5 rows x 41 columns]
# --- placeholder_invoice_20260324.parquet (5 primeiras linhas) ---
#   Balance BillAddr ClassRef CurrencyRef CustomerMemo CustomerRef  \
# 0       0     None     None        None         None        None
#
#   DepartmentRef DepositToAccountRef DocNumber     DueDate  ...  \
# 0          None                None  PH-INV-1  2026-02-14  ...
#
#            PrivateNote SalesTermRef ShipAddr    ShipDate SyncToken TotalAmt  \
# 0  Placeholder invoice         None     None  2026-02-07         1        0
#
#       TxnDate TxnTaxDetail domain sparse
# 0  2026-02-07         None    QBO  false
#
# [1 rows x 27 columns]

# %%
# Encerrar SparkSession
spark.stop()
print("SparkSession encerrada.")
# Out:
# SparkSession encerrada.
