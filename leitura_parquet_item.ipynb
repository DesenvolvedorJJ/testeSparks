# %% [markdown]
# # Leitura de Múltiplos Parquets com PySpark
#
# Notebook para ler todos os arquivos Parquet de uma pasta, detectar se contêm dados JSON e expandir automaticamente.

# %% [markdown]
# ## 1. Configurar SparkSession
#
# Importar PySpark e criar uma SparkSession.

# %%
from pyspark.sql import SparkSession

# Criar SparkSession
spark = SparkSession.builder \
    .appName("Leitura Parquet") \
    .master("local[*]") \
    .getOrCreate()

print(f"Spark version: {spark.version}")
spark
# Out:
# Spark version: 3.4.0
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://pc01:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Leitura Parquet</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## 2. Resumo dos Arquivos
#
# Tabela resumo mostrando quais arquivos têm JSON e quantos registros.

# %%
import glob
import os

# Pasta com os arquivos Parquet
pasta_parquet = "quickbooks_data/daily_incremental/item"

# Listar todos os arquivos .parquet
arquivos = glob.glob(os.path.join(pasta_parquet, "*.parquet"))
print(f"Arquivos encontrados: {len(arquivos)}\n")

# Dicionário para guardar os DataFrames
dataframes = {}

for arquivo in arquivos:
    nome = os.path.basename(arquivo)
    print(f"--- {nome} ---")
    df = spark.read.parquet(arquivo)
    registros = df.count()
    print(f"  Registros: {registros}")
    print(f"  Colunas: {df.columns}")

    # Detectar se alguma coluna contém JSON (string que começa com '{' ou '[')
    tem_json = False
    colunas_json = []
    for c in df.columns:
        # Verificar tipo string
        tipo = dict(df.dtypes).get(c)
        if tipo == "string" and registros > 0:
            amostra = df.select(c).filter(f"`{c}` IS NOT NULL").first()
            if amostra:
                valor = amostra[0]
                if isinstance(valor, str) and len(valor) > 0 and valor.strip()[0] in ('{', '['):
                    tem_json = True
                    colunas_json.append(c)

    if tem_json:
        print(f"  ✅ Contém JSON nas colunas: {colunas_json}")
    else:
        print(f"  ❌ Não contém dados JSON")

    dataframes[nome] = {"df": df, "tem_json": tem_json, "colunas_json": colunas_json}
    print()
# Out:
# Arquivos encontrados: 3
#
# --- Item_20260207170557.parquet ---
#   Registros: 2
#   Colunas: ['raw_value']
#   ❌ Não contém dados JSON
#
# --- Item_20260325043100.parquet ---
#   Registros: 10
#   Colunas: ['raw_value']
#   ✅ Contém JSON nas colunas: ['raw_value']
#
# --- placeholder_item_20260324.parquet ---
#   Registros: 1
#   Colunas: ['raw_value']
#   ✅ Contém JSON nas colunas: ['raw_value']

# %% [markdown]
# import pandas as pd
#
# resumo = []
# for nome, info in dataframes.items():
#     resumo.append({
#         "Arquivo": nome,
#         "Registros": info["df"].count(),
#         "Colunas": len(info["df"].columns),
#         "Tem JSON": "Sim" if info["tem_json"] else "Não",
#         "Colunas JSON": ", ".join(info["colunas_json"]) if info["colunas_json"] else "-"
#     })
#
# df_resumo = pd.DataFrame(resumo)
# df_resumo

# %% [markdown]
# ## 3. Verificar se as Colunas JSON são Iguais
#
# Comparar os schemas JSON de todos os arquivos que contêm JSON para verificar compatibilidade.

# %%
from pyspark.sql.functions import from_json, schema_of_json, col

# Coletar schemas JSON de cada arquivo
schemas_json = {}
for nome, info in dataframes.items():
    if not info["tem_json"]:
        continue
    df = info["df"]
    for col_json in info["colunas_json"]:
        amostra = df.select(col_json).filter(f"`{col_json}` IS NOT NULL").first()[0]
        json_schema = schema_of_json(amostra)
        # Parsear para obter o StructType real
        df_temp = df.withColumn("parsed", from_json(col(col_json), json_schema)).select("parsed.*")
        schemas_json[nome] = {
            "colunas": sorted(df_temp.columns),
            "schema": df_temp.schema,
            "dtypes": sorted(df_temp.dtypes, key=lambda x: x[0])
        }

# Comparar todos os schemas entre si
arquivos_com_json = list(schemas_json.keys())
print(f"Arquivos com JSON: {len(arquivos_com_json)}\n")

if len(arquivos_com_json) < 2:
    print("⚠️ Apenas 1 arquivo com JSON encontrado, nada para comparar.")
else:
    referencia = arquivos_com_json[0]
    colunas_ref = set(schemas_json[referencia]["colunas"])
    todos_iguais = True

    for arquivo in arquivos_com_json[1:]:
        colunas_atual = set(schemas_json[arquivo]["colunas"])

        print(f"Comparando: {referencia} vs {arquivo}")

        # Colunas iguais?
        if colunas_ref == colunas_atual:
            print(f"  ✅ Mesmas colunas ({len(colunas_ref)} colunas)")
        else:
            todos_iguais = False
            apenas_ref = colunas_ref - colunas_atual
            apenas_atual = colunas_atual - colunas_ref
            em_comum = colunas_ref & colunas_atual
            print(f"  ❌ Colunas diferentes!")
            print(f"     Em comum: {len(em_comum)} → {sorted(em_comum)}")
            if apenas_ref:
                print(f"     Só em {referencia}: {sorted(apenas_ref)}")
            if apenas_atual:
                print(f"     Só em {arquivo}: {sorted(apenas_atual)}")

        # Tipos iguais?
        dtypes_ref = schemas_json[referencia]["dtypes"]
        dtypes_atual = schemas_json[arquivo]["dtypes"]
        if dtypes_ref == dtypes_atual:
            print(f"  ✅ Tipos de dados idênticos")
        else:
            todos_iguais = False
            print(f"  ❌ Tipos de dados diferem:")
            for (col_r, tipo_r), (col_a, tipo_a) in zip(dtypes_ref, dtypes_atual):
                if col_r == col_a and tipo_r != tipo_a:
                    print(f"     Coluna '{col_r}': {tipo_r} → {tipo_a}")
        print()

    if todos_iguais:
        print("✅ RESULTADO: Todos os arquivos JSON têm exatamente as mesmas colunas e tipos!")
    else:
        print("❌ RESULTADO: Existem diferenças entre os schemas JSON dos arquivos.")
# Out:
# Arquivos com JSON: 2
#
# Comparando: Item_20260325043100.parquet vs placeholder_item_20260324.parquet
#   ✅ Mesmas colunas (29 colunas)
#   ✅ Tipos de dados idênticos
#
# ✅ RESULTADO: Todos os arquivos JSON têm exatamente as mesmas colunas e tipos!

# %%
from pyspark.sql.functions import from_json, schema_of_json, col
from pyspark.sql.types import StructType, StringType

def flatten_df(df, sep="_"):
    """Achata recursivamente colunas StructType em colunas simples."""
    colunas_complexas = True
    while colunas_complexas:
        colunas_complexas = False
        novas_colunas = []
        for field in df.schema.fields:
            if isinstance(field.dataType, StructType):
                colunas_complexas = True
                for sub in field.dataType.fields:
                    novo_nome = f"{field.name}{sep}{sub.name}"
                    novas_colunas.append(df[field.name][sub.name].alias(novo_nome))
            else:
                novas_colunas.append(df[field.name])
        df = df.select(novas_colunas)
    return df

def parse_nested_json(df, sep="_", max_depth=3):
    """Detecta e parseia colunas string que contêm JSON, depois achata."""
    for _ in range(max_depth):
        str_cols = [f.name for f in df.schema.fields if isinstance(f.dataType, StringType)]
        if not str_cols:
            break

        amostra = df.select(*[df[c] for c in str_cols]).filter(
            df[str_cols[0]].isNotNull()
        ).first()
        if not amostra:
            break

        cols_json = []
        for i, c in enumerate(str_cols):
            val = amostra[i]
            if val and isinstance(val, str) and val.strip() and val.strip()[0] in ('{', '['):
                cols_json.append((c, val))

        if not cols_json:
            break

        for c, val in cols_json:
            schema = schema_of_json(val)
            df = df.withColumn(c, from_json(df[c], schema))

        df = flatten_df(df, sep)
    return df

# Para cada arquivo com JSON, parsear, expandir sub-JSONs e achatar
for nome, info in dataframes.items():
    if not info["tem_json"]:
        print(f"--- {nome}: Sem JSON, mostrando dados diretos ---")
        info["df"].show(5, truncate=False)
        print()
        continue

    df = info["df"]
    for col_json in info["colunas_json"]:
        print(f"--- {nome} | Coluna: {col_json} ---")
        amostra = df.select(col_json).filter(df[col_json].isNotNull()).first()[0]
        json_schema = schema_of_json(amostra)

        df_parsed = df.withColumn("parsed", from_json(df[col_json], json_schema)) \
                      .select("parsed.*")

        colunas_antes = set(df_parsed.columns)

        # Parsear sub-JSONs e achatar tudo
        df_flat = parse_nested_json(df_parsed)

        colunas_expandidas = [c for c in df_flat.columns if c not in colunas_antes]
        if colunas_expandidas:
            print(f"Colunas JSON aninhadas expandidas: {colunas_expandidas}")

        print(f"Total de colunas: {len(df_flat.columns)}")
        df_flat.printSchema()
        df_flat.show(5, truncate=False)

        info["df_parsed"] = df_flat
    print()
# Out:
# --- Item_20260207170557.parquet: Sem JSON, mostrando dados diretos ---
# +-------------+
# |raw_value    |
# +-------------+
# |QueryResponse|
# |time         |
# +-------------+
#
#
# --- Item_20260325043100.parquet | Coluna: raw_value ---
# Colunas JSON aninhadas expandidas: ['AssetAccountRef_name', 'AssetAccountRef_value', 'ClassRef_name', 'ClassRef_value', 'ExpenseAccountRef_name', 'ExpenseAccountRef_value', 'IncomeAccountRef_name', 'IncomeAccountRef_value', 'MetaData_CreateTime', 'MetaData_LastUpdatedTime', 'MetaData_source', 'PurchaseTaxCodeRef_name', 'PurchaseTaxCodeRef_value', 'SalesTaxCodeRef_name', 'SalesTaxCodeRef_value']
# Total de colunas: 37
# root
#  |-- Active: string (nullable = true)
#  |-- AssetAccountRef_name: string (nullable = true)
#  |-- AssetAccountRef_value: string (nullable = true)
#  |-- ClassRef_name: string (nullable = true)
#  |-- ClassRef_value: string (nullable = true)
#  |-- Description: string (nullable = true)
#  |-- ExpenseAccountRef_name: string (nullable = true)
#  |-- ExpenseAccountRef_value: string (nullable = true)
#  |-- FullyQualifiedName: string (nullable = true)
#  |-- Id: string (nullable = true)
#  |-- IncomeAccountRef_name: string (nullable = true)
#  |-- IncomeAccountRef_value: string (nullable = true)
#  |-- InvStartDate: string (nullable = true)
#  |-- Level: string (nullable = true)
#  |-- MetaData_CreateTime: string (nullable = true)
#  |-- MetaData_LastUpdatedTime: string (nullable = true)
#  |-- MetaData_source: string (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- ParentRef: string (nullable = true)
#  |-- PurchaseCost: string (nullable = true)
#  |-- PurchaseDesc: string (nullable = true)
#  |-- PurchaseTaxCodeRef_name: string (nullable = true)
#  |-- PurchaseTaxCodeRef_value: string (nullable = true)
#  |-- QtyOnHand: string (nullable = true)
#  |-- ReorderPoint: string (nullable = true)
#  |-- SalesTaxCodeRef_name: string (nullable = true)
#  |-- SalesTaxCodeRef_value: string (nullable = true)
#  |-- SalesTaxIncluded: string (nullable = true)
#  |-- Sku: string (nullable = true)
#  |-- SubItem: string (nullable = true)
#  |-- SyncToken: string (nullable = true)
#  |-- Taxable: string (nullable = true)
#  |-- TrackQtyOnHand: string (nullable = true)
#  |-- Type: string (nullable = true)
#  |-- UnitPrice: string (nullable = true)
#  |-- domain: string (nullable = true)
#  |-- sparse: string (nullable = true)
#
# +------+--------------------+---------------------+-------------+--------------+-----------------------+----------------------+-----------------------+------------------+--------+---------------------+----------------------+------------+-----+--------------------+------------------------+---------------+----------------+---------+------------+---------------------+-----------------------+------------------------+---------+------------+--------------------+---------------------+----------------+--------+-------+---------+-------+--------------+-------+---------+------+------+
# |Active|AssetAccountRef_name|AssetAccountRef_value|ClassRef_name|ClassRef_value|Description            |ExpenseAccountRef_name|ExpenseAccountRef_value|FullyQualifiedName|Id      |IncomeAccountRef_name|IncomeAccountRef_value|InvStartDate|Level|MetaData_CreateTime |MetaData_LastUpdatedTime|MetaData_source|Name            |ParentRef|PurchaseCost|PurchaseDesc         |PurchaseTaxCodeRef_name|PurchaseTaxCodeRef_value|QtyOnHand|ReorderPoint|SalesTaxCodeRef_name|SalesTaxCodeRef_value|SalesTaxIncluded|Sku     |SubItem|SyncToken|Taxable|TrackQtyOnHand|Type   |UnitPrice|domain|sparse|
# +------+--------------------+---------------------+-------------+--------------+-----------------------+----------------------+-----------------------+------------------+--------+---------------------+----------------------+------------+-----+--------------------+------------------------+---------------+----------------+---------+------------+---------------------+-----------------------+------------------------+---------+------------+--------------------+---------------------+----------------+--------+-------+---------+-------+--------------+-------+---------+------+------+
# |true  |Operating Account 1 |acct-001             |General      |class-001     |Dental procedure item 1|Office Expense        |acct-002               |Procedure Item 1  |item-001|Service Income       |acct-003              |2025-02-01  |0    |2026-02-02T09:00:00Z|2026-03-02T09:30:00Z    |item           |Procedure Item 1|null     |24.50       |Purchase descriptor 1|Non                    |NON                     |6        |3           |Non                 |NON                  |false           |SKU-7001|false  |601      |false  |true          |Service|110.00   |QBO   |false |
# |true  |Operating Account 1 |acct-001             |General      |class-001     |Dental procedure item 2|Office Expense        |acct-002               |Procedure Item 2  |item-002|Service Income       |acct-003              |2025-03-01  |0    |2026-02-03T09:00:00Z|2026-03-03T10:30:00Z    |item           |Procedure Item 2|null     |29.00       |Purchase descriptor 2|Non                    |NON                     |7        |4           |Non                 |NON                  |false           |SKU-7002|false  |602      |false  |true          |Service|125.00   |QBO   |false |
# |true  |Operating Account 1 |acct-001             |General      |class-001     |Dental procedure item 3|Office Expense        |acct-002               |Procedure Item 3  |item-003|Service Income       |acct-003              |2025-04-01  |0    |2026-02-04T09:00:00Z|2026-03-04T11:30:00Z    |item           |Procedure Item 3|null     |33.50       |Purchase descriptor 3|Non                    |NON                     |8        |2           |Non                 |NON                  |false           |SKU-7003|false  |603      |false  |true          |Service|140.00   |QBO   |false |
# |true  |Operating Account 1 |acct-001             |General      |class-001     |Dental procedure item 4|Office Expense        |acct-002               |Procedure Item 4  |item-004|Service Income       |acct-003              |2025-05-01  |0    |2026-02-05T09:00:00Z|2026-03-05T12:30:00Z    |item           |Procedure Item 4|null     |38.00       |Purchase descriptor 4|Non                    |NON                     |9        |3           |Non                 |NON                  |false           |SKU-7004|false  |604      |false  |true          |Service|155.00   |QBO   |false |
# |true  |Operating Account 1 |acct-001             |General      |class-001     |Dental procedure item 5|Office Expense        |acct-002               |Procedure Item 5  |item-005|Service Income       |acct-003              |2025-06-01  |0    |2026-02-06T09:00:00Z|2026-03-06T13:30:00Z    |item           |Procedure Item 5|null     |42.50       |Purchase descriptor 5|Non                    |NON                     |10       |4           |Non                 |NON                  |false           |SKU-7005|false  |605      |false  |true          |Service|170.00   |QBO   |false |
# +------+--------------------+---------------------+-------------+--------------+-----------------------+----------------------+-----------------------+------------------+--------+---------------------+----------------------+------------+-----+--------------------+------------------------+---------------+----------------+---------+------------+---------------------+-----------------------+------------------------+---------+------------+--------------------+---------------------+----------------+--------+-------+---------+-------+--------------+-------+---------+------+------+
# only showing top 5 rows
#
#
# --- placeholder_item_20260324.parquet | Coluna: raw_value ---
# Total de colunas: 29
# root
#  |-- Active: string (nullable = true)
#  |-- AssetAccountRef: string (nullable = true)
#  |-- ClassRef: string (nullable = true)
#  |-- Description: string (nullable = true)
#  |-- ExpenseAccountRef: string (nullable = true)
#  |-- FullyQualifiedName: string (nullable = true)
#  |-- Id: string (nullable = true)
#  |-- IncomeAccountRef: string (nullable = true)
#  |-- InvStartDate: string (nullable = true)
#  |-- Level: string (nullable = true)
#  |-- MetaData: string (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- ParentRef: string (nullable = true)
#  |-- PurchaseCost: string (nullable = true)
#  |-- PurchaseDesc: string (nullable = true)
#  |-- PurchaseTaxCodeRef: string (nullable = true)
#  |-- QtyOnHand: string (nullable = true)
#  |-- ReorderPoint: string (nullable = true)
#  |-- SalesTaxCodeRef: string (nullable = true)
#  |-- SalesTaxIncluded: string (nullable = true)
#  |-- Sku: string (nullable = true)
#  |-- SubItem: string (nullable = true)
#  |-- SyncToken: string (nullable = true)
#  |-- Taxable: string (nullable = true)
#  |-- TrackQtyOnHand: string (nullable = true)
#  |-- Type: string (nullable = true)
#  |-- UnitPrice: string (nullable = true)
#  |-- domain: string (nullable = true)
#  |-- sparse: string (nullable = true)
#
# +------+---------------+--------+----------------+-----------------+------------------+------------------+----------------+------------+-----+--------+----------------+---------+------------+------------+------------------+---------+------------+---------------+----------------+---------+-------+---------+-------+--------------+-------+---------+------+------+
# |Active|AssetAccountRef|ClassRef|Description     |ExpenseAccountRef|FullyQualifiedName|Id                |IncomeAccountRef|InvStartDate|Level|MetaData|Name            |ParentRef|PurchaseCost|PurchaseDesc|PurchaseTaxCodeRef|QtyOnHand|ReorderPoint|SalesTaxCodeRef|SalesTaxIncluded|Sku      |SubItem|SyncToken|Taxable|TrackQtyOnHand|Type   |UnitPrice|domain|sparse|
# +------+---------------+--------+----------------+-----------------+------------------+------------------+----------------+------------+-----+--------+----------------+---------+------------+------------+------------------+---------+------------+---------------+----------------+---------+-------+---------+-------+--------------+-------+---------+------+------+
# |true  |null           |null    |Placeholder item|null             |Placeholder Item  |placeholder-item-1|null            |2026-02-07  |0    |null    |Placeholder Item|null     |0           |null        |null              |0        |0           |null           |false           |PH-ITEM-1|false  |1        |false  |false         |Service|0        |QBO   |false |
# +------+---------------+--------+----------------+-----------------+------------------+------------------+----------------+------------+-----+--------+----------------+---------+------------+------------+------------------+---------+------------+---------------+----------------+---------+-------+---------+-------+--------------+-------+---------+------+------+

# %%
from IPython.display import display
from functools import reduce
from pyspark.sql.functions import col, count, when
from pyspark.sql.types import StringType

# Juntar todos os DataFrames parseados em um só, tratando diferenças de schema e tipos
dfs_parsed = [info["df_parsed"] for info in dataframes.values() if "df_parsed" in info]

if dfs_parsed:
    # Converter todas as colunas para string para evitar conflitos de tipo no union
    dfs_str = []
    for df in dfs_parsed:
        df_str = df.select([col(c).cast(StringType()).alias(c) for c in df.columns])
        dfs_str.append(df_str)

    df_merged = reduce(lambda a, b: a.unionByName(b, allowMissingColumns=True), dfs_str)

    # Identificar e remover colunas que são totalmente nulas
    total = df_merged.count()
    nulls_por_coluna = df_merged.select(
        [count(when(col(c).isNull(), c)).alias(c) for c in df_merged.columns]
    ).first()

    colunas_nulas = [c for c in df_merged.columns if nulls_por_coluna[c] == total]
    if colunas_nulas:
        print(f"Colunas totalmente nulas removidas: {colunas_nulas}")
        df_merged = df_merged.drop(*colunas_nulas)

    print(f"Total de linhas: {total} | Total de colunas: {len(df_merged.columns)}")
    display(df_merged.limit(10).toPandas())
else:
    print("Nenhum DataFrame parseado encontrado.")
# Out:
# Colunas totalmente nulas removidas: ['ParentRef', 'AssetAccountRef', 'ClassRef', 'ExpenseAccountRef', 'IncomeAccountRef', 'MetaData', 'PurchaseTaxCodeRef', 'SalesTaxCodeRef']
# Total de linhas: 11 | Total de colunas: 36
#   Active AssetAccountRef_name AssetAccountRef_value ClassRef_name  \
# 0   true  Operating Account 1              acct-001       General
# 1   true  Operating Account 1              acct-001       General
# 2   true  Operating Account 1              acct-001       General
# 3   true  Operating Account 1              acct-001       General
# 4   true  Operating Account 1              acct-001       General
# 5   true  Operating Account 1              acct-001       General
# 6   true  Operating Account 1              acct-001       General
# 7   true  Operating Account 1              acct-001       General
# 8   true  Operating Account 1              acct-001       General
# 9   true  Operating Account 1              acct-001       General
#
#   ClassRef_value               Description ExpenseAccountRef_name  \
# 0      class-001   Dental procedure item 1         Office Expense
# 1      class-001   Dental procedure item 2         Office Expense
# 2      class-001   Dental procedure item 3         Office Expense
# 3      class-001   Dental procedure item 4         Office Expense
# 4      class-001   Dental procedure item 5         Office Expense
# 5      class-001   Dental procedure item 6         Office Expense
# 6      class-001   Dental procedure item 7         Office Expense
# 7      class-001   Dental procedure item 8         Office Expense
# 8      class-001   Dental procedure item 9         Office Expense
# 9      class-001  Dental procedure item 10         Office Expense
#
#   ExpenseAccountRef_value FullyQualifiedName        Id  ... SalesTaxIncluded  \
# 0                acct-002   Procedure Item 1  item-001  ...            false
# 1                acct-002   Procedure Item 2  item-002  ...            false
# 2                acct-002   Procedure Item 3  item-003  ...            false
# 3                acct-002   Procedure Item 4  item-004  ...            false
# 4                acct-002   Procedure Item 5  item-005  ...            false
# 5                acct-002   Procedure Item 6  item-006  ...            false
# 6                acct-002   Procedure Item 7  item-007  ...            false
# 7                acct-002   Procedure Item 8  item-008  ...            false
# 8                acct-002   Procedure Item 9  item-009  ...            false
# 9                acct-002  Procedure Item 10  item-010  ...            false
#
#         Sku SubItem SyncToken Taxable TrackQtyOnHand     Type UnitPrice  \
# 0  SKU-7001   false       601   false           true  Service    110.00
# 1  SKU-7002   false       602   false           true  Service    125.00
# 2  SKU-7003   false       603   false           true  Service    140.00
# 3  SKU-7004   false       604   false           true  Service    155.00
# 4  SKU-7005   false       605   false           true  Service    170.00
# 5  SKU-7006   false       606   false           true  Service    185.00
# 6  SKU-7007   false       607   false           true  Service    200.00
# 7  SKU-7008   false       608   false           true  Service    215.00
# 8  SKU-7009   false       609   false           true  Service    230.00
# 9  SKU-7010   false       610   false           true  Service    245.00
#
#   domain sparse
# 0    QBO  false
# 1    QBO  false
# 2    QBO  false
# 3    QBO  false
# 4    QBO  false
# 5    QBO  false
# 6    QBO  false
# 7    QBO  false
# 8    QBO  false
# 9    QBO  false
#
# [10 rows x 36 columns]

# %%
# Encerrar SparkSession
spark.stop()
print("SparkSession encerrada.")
# Out:
# SparkSession encerrada.
